# %% [markdown]
# ## Aponti Academy - Indicadores e Fatores Associados a Acidentes de Trânsito 2025

# %% [markdown]
# ### Base de Acidentes (Acidentes2025.csv)

# %% [markdown]
#  #### Base de dados:

# %% [markdown]
# - id = Identificador único do acidente na base de dados.
# - data_inversa = Data da ocorrência do acidente.
# - dia_semana = semana ocorrida no acidente
# - horario = Horário da ocorrência do acidente.
# - uf = Unidade da Federação (estado) onde ocorreu o acidente.
# - br = Número da rodovia federal (BR) onde ocorreu o acidente.
# - km = Quilômetro da rodovia onde ocorreu o acidente.
# - municipio = Município da ocorrência do acidente.
# - causa_acidente = Causa presumível do acidente identificada pela PRF.
# - tipo_acidente = Tipo do acidente (colisão frontal, saída de pista, capotamento, atropelamento etc.)
# - classificacao_acidente = Classificação da gravidade do acidente (sem vítimas, com vítimas feridas ou com vítimas fatais).
# - fase_dia = Período do dia em que ocorreu o acidente (amanhecer, pleno dia, anoitecer, plena noite etc.).
# - sentido_via = Sentido da via no local do acidente (crescente ou decrescente).
# - condicao_metereologica = Condição climática no momento do acidente (céu claro, chuva, neblina, vento etc.).

# %% [markdown]
# - tipo_pista = Tipo de pista da rodovia (simples, dupla ou múltipla).
# - tracado_via = Característica geométrica da via (reta, curva, cruzamento, viaduto, interseção etc.).
# - uso_solo = Classificação da área onde ocorreu o acidente (urbana ou rural).
# - pessoas = Quantidade total de pessoas envolvidas na ocorrência.
# - mortos = Quantidade de pessoas que morreram em decorrência do acidente.
# - feridos_leves = Quantidade de pessoas com ferimentos leves.
# - feridos_graves = Quantidade de pessoas com ferimentos graves.
# - ilesos = Quantidade de pessoas envolvidas que não sofreram ferimentos.
# - ignorados = Quantidade de pessoas cujo estado físico não foi identificado ou informado.
# - feridos = Total de pessoas feridas (soma de feridos leves e graves).
# - veiculos = Quantidade total de veículos envolvidos no acidente.
# - latitude = Coordenada geográfica de latitude do local do acidente.
# - longitude = Coordenada geográfica de longitude do local do acidente.
# - regional = Superintendência Regional da PRF responsável pela ocorrência.
# - delegacia = Delegacia da PRF responsável pelo atendimento da ocorrência.
# - uop = Unidade Operacional da PRF responsável pelo registro ou atendimento da ocorrência.

# %% [markdown]
# #### Problema analítico central

# %% [markdown]
# - O presente projeto análitico visa mitigar o alto índice de acidentes severos e fatais nas rodovias federais brasileiras em 2025. A partir da análise dos registros de ocorrências da Polícia Rodoviária Federal (PRF),  o objetivo é estruturar indicadores-chave que permitam diagnosticar as causas - raiz dos acidentes, identificar padrões espaciais, temporais e ambientais, e correlacionar variáveis operacionais para compreender os fatores de maior letalidade. Com isso, pretende-se fornecer insights que subsidiem ações preventivas eficazes, como realocação de patrulhamento e melhorias na sinalização, contribuindo para a redução da severidade dos acidentes e preservação de vidas nas rodovias federais.

# %% [markdown]
# #### Objetivo Geral

# %% [markdown]
# - Realizar uma análise exploratória dos dados de acidentes rodoviários registrados pela Polícia Rodoviária Federal em 2025, utilizando a programação, para calcular indicadores globais, identificar padrões e correlações entre variáveis operacionais, espaciais, temporais e ambientais, com o propósito de diagnosticar as causas dos acidentes e gerar recomendações preventivas para redução da letalidade nas rodovias federais Brasileiras.

# %% [markdown]
# #### Importação das bibliotecas

# %%
import pandas as pd
import numpy as np

# %%
conda remove seaborn matplotlib
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/gustavo/anaconda3
#
#   removed specs:
#     - matplotlib
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |           52_gnu           7 KB
#     alsa-lib-1.2.15.3          |       h47b2149_0         570 KB
#     anaconda-anon-usage-0.8.1  |   pyhb46e38b_100          24 KB
#     anaconda-auth-0.10.0       |   py39h06a4308_1          68 KB
#     anaconda-cli-base-0.5.4    |   py39h06a4308_0          38 KB
#     anaconda-client-1.13.1     |   py39h06a4308_0         767 KB
#     anaconda-navigator-2.7.0   |   py39h06a4308_1         4.8 MB
#     annotated-types-0.6.0      |   py39h06a4308_1          22 KB
#     anyio-4.10.0               |   py39h06a4308_0         224 KB
#     aom-3.13.2                 |       h664349e_0         2.7 MB
#     archspec-0.2.5             |     pyhd3eb1b0_0          48 KB
#     argon2-cffi-bindings-25.1.0|   py39hee96239_0          33 KB
#     asttokens-3.0.0            |   py39h06a4308_0          39 KB
#     async-lru-2.0.5            |   py39h06a4308_0          18 KB
#     attrs-25.4.0               |   py39h06a4308_1         151 KB
#     babel-2.16.0               |   py39h06a4308_0         6.8 MB
#     backcall-0.2.0             |     pyhd3eb1b0_1          15 KB
#     backports-1.1              |     pyhd3eb1b0_1           6 KB
#     backports.tarfile-1.2.0    |   py39h06a4308_0          55 KB
#     beautifulsoup4-4.13.5      |   py39h06a4308_0         215 KB
#     bleach-6.2.0               |   py39h06a4308_0         281 KB
#     boltons-25.0.0             |   py39h06a4308_0         426 KB
#     brotlicffi-1.0.9.2         |   py39hbdd6827_2         325 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     c-ares-1.34.7              |       hd44998d_0         204 KB
#     ca-certificates-2026.7.16  |       h06a4308_0         106 KB
#     cairo-1.18.4               |       h44eff21_0         728 KB
#     certifi-2025.10.5          |   py39h06a4308_0         157 KB
#     cffi-2.0.0                 |   py39h4eded50_0         235 KB
#     chardet-5.2.0              |   py39h06a4308_0         1.9 MB
#     charset-normalizer-3.4.4   |   py39h06a4308_0          79 KB
#     click-8.1.8                |   py39h06a4308_0         271 KB
#     comm-0.2.1                 |   py39h06a4308_0          14 KB
#     conda-25.9.1               |   py39h06a4308_0         923 KB
#     conda-build-25.9.0         |   py39h76456e7_0         568 KB
#     conda-index-0.7.0          |   py39h06a4308_0         233 KB
#     conda-libmamba-solver-25.4.0|     pyhdf14ebd_1          39 KB
#     conda-package-handling-2.4.0|   py39h06a4308_0         272 KB
#     conda-package-streaming-0.12.0|   py39h06a4308_0          32 KB
#     conda-repo-cli-1.0.173     |   py39h06a4308_0         160 KB
#     cpp-expected-1.1.0         |       hdb19cb5_0         130 KB
#     cryptography-46.0.2        |   py39h498d7c9_0         1.6 MB
#     cyrus-sasl-2.1.28          |       h1110e0f_3         242 KB
#     dav1d-1.5.3                |       h12c9f22_1         766 KB
#     dbus-1.16.2                |       h5bd4931_0         1.2 MB
#     debugpy-1.8.16             |   py39hbdd6827_0         2.1 MB
#     decorator-5.2.1            |   py39h06a4308_0          38 KB
#     distro-1.9.0               |   py39h06a4308_0          31 KB
#     evalidate-2.0.3            |   py39h06a4308_0          18 KB
#     exceptiongroup-1.2.0       |   py39h06a4308_0          29 KB
#     executing-2.2.1            |   py39h06a4308_0         329 KB
#     expat-2.8.2                |       h7354ed3_1          24 KB
#     filelock-3.17.0            |   py39h06a4308_0          32 KB
#     fmt-11.2.0                 |       hca5f364_0         202 KB
#     fontconfig-2.15.0          |       h2c49b7f_0         262 KB
#     freetype-2.14.1            |       hf5b9546_0         634 KB
#     fribidi-1.0.16             |       h10f3c28_1          58 KB
#     frozendict-2.4.6           |   py39hee96239_0          57 KB
#     future-1.0.0               |   py39h06a4308_0         684 KB
#     gettext-0.25.1             |       h92eb808_0         523 KB
#     gettext-tools-0.25.1       |       h6a67909_0         3.6 MB
#     graphite2-1.3.15           |       h9ba177b_0          93 KB
#     h11-0.16.0                 |   py39h06a4308_0          53 KB
#     harfbuzz-10.2.0            |       hdfddeaa_1         2.3 MB
#     httpcore-1.0.9             |   py39h06a4308_0          91 KB
#     httpx-0.28.1               |   py39h06a4308_1         173 KB
#     icu-73.1                   |       h6a678d5_0        25.9 MB
#     idna-3.11                  |   py39h06a4308_0         183 KB
#     importlib-metadata-8.5.0   |   py39h06a4308_0          44 KB
#     importlib_metadata-8.5.0   |       hd3eb1b0_0           9 KB
#     intel-openmp-2025.0.0      |    h06a4308_1172        19.3 MB
#     ipykernel-6.30.1           |   py39h06a4308_0         198 KB
#     ipython-8.15.0             |   py39h06a4308_0         1.1 MB
#     ipywidgets-8.1.7           |   py39h06a4308_0         194 KB
#     jansson-2.15.0             |       hbcba0ee_0          65 KB
#     jaraco.classes-3.4.0       |   py39h06a4308_0          18 KB
#     jaraco.context-6.0.0       |   py39h06a4308_0          15 KB
#     jaraco.functools-4.1.0     |   py39h06a4308_0          20 KB
#     jedi-0.19.2                |   py39h06a4308_0         1.1 MB
#     jinja2-3.1.6               |   py39h06a4308_0         274 KB
#     jpeg-9f                    |       h5ce9db8_0         242 KB
#     json5-0.9.25               |   py39h06a4308_0          43 KB
#     jsonpatch-1.33             |   py39h06a4308_1          31 KB
#     jsonpointer-3.0.0          |   py39h06a4308_0          19 KB
#     jsonschema-4.25.0          |   py39h06a4308_0         156 KB
#     jsonschema-specifications-2023.7.1|   py39h06a4308_0          15 KB
#     jupyter-lsp-2.2.5          |   py39h06a4308_0          92 KB
#     jupyter_client-8.6.3       |   py39h06a4308_0         184 KB
#     jupyter_core-5.8.1         |   py39h06a4308_0          82 KB
#     jupyter_events-0.12.0      |   py39h06a4308_0          37 KB
#     jupyter_server-2.16.0      |   py39h06a4308_0         499 KB
#     jupyter_server_terminals-0.5.3|   py39h06a4308_0          25 KB
#     jupyterlab-4.4.7           |   py39h06a4308_0         7.9 MB
#     jupyterlab_pygments-0.3.0  |   py39h06a4308_0          18 KB
#     jupyterlab_server-2.28.0   |   py39h06a4308_0          95 KB
#     jupyterlab_widgets-3.0.16  |     pyhd3eb1b0_2         185 KB
#     keyring-25.6.0             |   py39h06a4308_0          68 KB
#     lcms2-2.19                 |       he283960_0         243 KB
#     ld_impl_linux-64-2.44      |       h9e0c5a2_3         725 KB
#     lerc-4.1.0                 |       h7354ed3_2         266 KB
#     libabseil-20260526.0       | cxx17_h724b069_0         1.4 MB
#     libarchive-3.8.2           |       h3ec8f01_0         855 KB
#     libasprintf-0.25.1         |       hf2ab22a_0          51 KB
#     libasprintf-devel-0.25.1   |       hf2ab22a_0          33 KB
#     libavif-1.3.0              |       h2b90b00_1         151 KB
#     libclang13-22.1.2          |default_hc2d2b39_2        12.0 MB
#     libcups-2.4.19             |       h23114ae_0         4.4 MB
#     libcurl-8.17.0             |       hc93bc37_0         471 KB
#     libdeflate-1.22            |       h5eee18b_0          68 KB
#     libdrm-2.4.134             |       h9c74679_0         305 KB
#     libegl-1.7.0               |       h5eee18b_2          44 KB
#     libevent-2.1.12            |       hdbd6064_1         453 KB
#     libexpat-2.8.2             |       h7354ed3_1         126 KB
#     libffi-3.4.8               |       h06d3fd0_3         137 KB
#     libgcc-15.2.0              |       h69a1729_8         803 KB
#     libgcc-ng-15.2.0           |       h166f726_8          28 KB
#     libgettextpo-0.25.1        |       hf2ab22a_0         186 KB
#     libgettextpo-devel-0.25.1  |       hf2ab22a_0          35 KB
#     libgl-1.7.0                |       h5eee18b_2         149 KB
#     libglib-2.88.3             |       ha16e27a_0         3.9 MB
#     libglvnd-1.7.0             |       h5eee18b_2         140 KB
#     libglx-1.7.0               |       h5eee18b_2          87 KB
#     libhwloc-2.12.1            |default_hf1bbc79_1000         2.4 MB
#     libiconv-1.18              |       h75a1612_0         771 KB
#     libidn2-2.3.8              |       hf80d704_0          80 KB
#     libkrb5-1.21.3             |       h520c7b4_4         874 KB
#     liblief-0.16.4             |       h6a678d5_0         2.1 MB
#     libllvm22-22.1.2           |       hfb1d434_0        43.4 MB
#     libmamba-2.3.2             |       h4368100_0         2.0 MB
#     libmambapy-2.3.2           |   py39hea2f153_0         647 KB
#     libnghttp2-1.67.1          |       h697f920_0         636 KB
#     libnsl-2.0.0               |       h5eee18b_0          31 KB
#     libopenjpeg-2.5.4          |       hee96239_1         215 KB
#     libopus-1.6.1              |       h9f10d21_0         289 KB
#     libpciaccess-0.18          |       h5eee18b_0          26 KB
#     libpng-1.6.56              |       h22898a0_0         243 KB
#     libpq-17.6                 |       ha51bf15_0         2.5 MB
#     libre2-11-2025.11.05       |       h7354ed3_2         206 KB
#     libsodium-1.0.21           |       h83fc4cd_1         287 KB
#     libsolv-0.7.39             |       h04d0c11_0         471 KB
#     libssh2-1.11.1             |       hfbabe93_1         296 KB
#     libstdcxx-15.2.0           |       h39759b7_8         3.7 MB
#     libstdcxx-ng-15.2.0        |       hc03a8fd_8          28 KB
#     libtiff-4.7.1              |       h029b1ac_0         423 KB
#     libunistring-1.4.2         |       h34b0ebb_0         656 KB
#     libuuid-1.41.5             |       h5eee18b_0          27 KB
#     libvpx-1.15.2              |       h4cb591d_0         1.2 MB
#     libwebp-base-1.6.0         |       hb7bb969_0         419 KB
#     libxcb-1.17.0              |       h9b100fa_0         430 KB
#     libxkbcommon-1.9.1         |       h69220b7_0         732 KB
#     libxkbfile-1.1.0           |       hf54ef8a_2         126 KB
#     libxml2-2.13.9             |       h2c43086_0         669 KB
#     libxslt-1.1.43             |       h28b3bda_0         240 KB
#     libzlib-1.3.2              |       h47b2149_0          60 KB
#     lmdb-1.0.0                 |       hfe55579_0         518 KB
#     lz4-c-1.9.4                |       h7354ed3_5         144 KB
#     markdown-it-py-2.2.0       |   py39h06a4308_1         113 KB
#     markupsafe-3.0.2           |   py39h5eee18b_0          24 KB
#     matplotlib-inline-0.1.7    |   py39h06a4308_0          17 KB
#     mbedtls-3.5.1              |       h6a678d5_1         972 KB
#     mdurl-0.1.2                |   py39h06a4308_0          23 KB
#     menuinst-2.4.1             |   py39h06a4308_0         221 KB
#     mesalib-25.1.5             |       h3583ad3_5         8.3 MB
#     mistune-3.1.2              |   py39h06a4308_0         117 KB
#     mkl-2025.0.0               |     h6d8faa4_942       113.4 MB
#     mkl-service-2.5.2          |   py39hacdc0fc_0          72 KB
#     mkl_fft-1.3.11             |   py39hacdc0fc_1         219 KB
#     mkl_random-1.3.0           |   py39h505adc9_0         301 KB
#     more-itertools-10.8.0      |   py39h06a4308_0         137 KB
#     msgpack-python-1.1.1       |   py39h6a678d5_0         112 KB
#     mysql-common-9.3.0         |       h9e076cb_6         612 KB
#     mysql-libs-9.3.0           |       he5ffe59_6         1.3 MB
#     navigator-updater-0.6.0    |   py39h06a4308_0         2.1 MB
#     nbclient-0.10.2            |   py39h06a4308_0          42 KB
#     nbconvert-core-7.16.6      |   py39h06a4308_0         475 KB
#     nbformat-5.10.4            |   py39h06a4308_0         138 KB
#     ncurses-6.5                |       h7934f7d_0         1.1 MB
#     nest-asyncio-1.6.0         |   py39h06a4308_0          14 KB
#     nlohmann_json-3.11.2       |       h6a678d5_0         124 KB
#     notebook-shim-0.2.4        |   py39h06a4308_0          22 KB
#     nspr-4.39                  |       h6e5897e_0         323 KB
#     nss-3.125                  |       hcf7f90d_0         1.9 MB
#     numpy-2.0.2                |   py39h64c44e4_2          13 KB
#     numpy-base-2.0.2           |   py39he1678cf_2         7.4 MB
#     openjpeg-2.5.4             |       h4e0627c_1          94 KB
#     openldap-2.6.12            |       h007892f_1         760 KB
#     openssl-3.5.7              |       h1b28b03_0         5.5 MB
#     overrides-7.4.0            |   py39h06a4308_0          29 KB
#     packaging-25.0             |   py39h06a4308_1         160 KB
#     pandocfilters-1.5.1        |   py39h06a4308_0          15 KB
#     parso-0.8.4                |   py39h06a4308_0         188 KB
#     patch-2.8                  |       hb25bd0a_0         119 KB
#     patchelf-0.17.2            |       h6a678d5_0          98 KB
#     pcre2-10.46                |       hf426167_0         1.2 MB
#     pexpect-4.9.0              |   py39h06a4308_0         138 KB
#     pillow-11.3.0              |   py39hb1c3d2d_0         826 KB
#     pip-26.0.1                 |     pyhc872135_1         1.1 MB
#     pixman-0.46.4              |       h86ba9f7_1         329 KB
#     pkce-1.0.3                 |   py39h06a4308_0           8 KB
#     pkginfo-1.12.0             |   py39h06a4308_0          55 KB
#     platformdirs-4.3.7         |   py39h06a4308_0          36 KB
#     pluggy-1.5.0               |   py39h06a4308_0          37 KB
#     prometheus_client-0.21.1   |   py39h06a4308_0         121 KB
#     prompt-toolkit-3.0.52      |   py39h06a4308_1         545 KB
#     psutil-7.0.0               |   py39hee96239_1         416 KB
#     pthread-stubs-0.3          |       h47b2149_2           7 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_3          18 KB
#     pure_eval-0.2.3            |   py39h06a4308_0          28 KB
#     py-lief-0.16.4             |   py39h6a678d5_0         1.6 MB
#     pybind11-abi-4             |       hd3eb1b0_1          14 KB
#     pycosat-0.6.6              |   py39h5eee18b_2          88 KB
#     pycparser-2.23             |   py39h06a4308_0         224 KB
#     pydantic-2.12.2            |   py39h06a4308_0         874 KB
#     pydantic-core-2.41.4       |   py39h498d7c9_0         1.8 MB
#     pydantic-settings-2.10.1   |   py39h06a4308_0         102 KB
#     pygments-2.19.1            |   py39h06a4308_0         1.9 MB
#     pyjwt-2.10.1               |   py39h06a4308_0          75 KB
#     pyside6-6.9.2              |   py39h2ddcaae_0        12.0 MB
#     pysocks-1.7.1              |   py39h06a4308_1          29 KB
#     python-3.9.25              |       h0dcde21_1        23.0 MB
#     python-dateutil-2.9.0post0 |   py39h06a4308_2         279 KB
#     python-dotenv-1.1.0        |   py39h06a4308_0          39 KB
#     python-fastjsonschema-2.20.0|   py39h06a4308_0         249 KB
#     python-json-logger-3.2.1   |   py39h06a4308_0          24 KB
#     python-libarchive-c-5.1    |     pyhd3eb1b0_0          50 KB
#     pytz-2025.2                |   py39h06a4308_0         228 KB
#     pyyaml-6.0.2               |   py39h5eee18b_0         192 KB
#     pyzmq-27.1.0               |   py39hcf8288c_0         326 KB
#     qtbase-6.9.2               |       hd13baf8_5        11.1 MB
#     qtdeclarative-6.9.2        |       h55666de_1        16.7 MB
#     qtpy-2.4.3                 |   py39h06a4308_0         109 KB
#     qtshadertools-6.9.2        |       hbdd6827_1         1.7 MB
#     qtsvg-6.9.2                |       h75a08ff_1         305 KB
#     qttools-6.9.2              |       hc856bc8_1         6.1 MB
#     qtwebchannel-6.9.2         |       hbdd6827_1         143 KB
#     qtwebengine-6.9.2          |       hbdb40ff_1       108.5 MB
#     qtwebsockets-6.9.2         |       hbdd6827_1         126 KB
#     re2-2025.11.05             |       h71b5c5c_2          25 KB
#     readchar-4.2.1             |   py39h06a4308_0          19 KB
#     readline-8.3               |       hc2a1206_0         471 KB
#     referencing-0.30.2         |   py39h06a4308_0          61 KB
#     reproc-14.2.7              |       h7bdf020_0          32 KB
#     reproc-cpp-14.2.7          |       h7bdf020_0          24 KB
#     requests-2.32.5            |   py39h06a4308_0         149 KB
#     requests-toolbelt-1.0.0    |   py39h06a4308_0          72 KB
#     rfc3339-validator-0.1.4    |   py39h06a4308_0           9 KB
#     rfc3986-validator-0.1.1    |   py39h06a4308_0           9 KB
#     rich-14.2.0                |   py39h06a4308_0         446 KB
#     rpds-py-0.22.3             |   py39h4aa5aa6_0         369 KB
#     ruamel.yaml-0.18.10        |   py39h5eee18b_0         202 KB
#     ruamel.yaml.clib-0.2.12    |   py39h5eee18b_0         159 KB
#     secretstorage-3.3.1        |   py39h06a4308_1          26 KB
#     semver-3.0.4               |   py39h06a4308_0          38 KB
#     send2trash-1.8.2           |   py39h06a4308_1          27 KB
#     setuptools-72.1.0          |   py39h06a4308_0         2.4 MB
#     shellingham-1.5.4          |   py39h06a4308_0          19 KB
#     simdjson-3.10.1            |       hdb19cb5_0         258 KB
#     six-1.17.0                 |   py39h06a4308_0          31 KB
#     snappy-1.2.2               |       h4bcf44c_1          46 KB
#     sniffio-1.3.0              |   py39h06a4308_0          16 KB
#     soupsieve-2.5              |   py39h06a4308_0          69 KB
#     spirv-tools-2026.1         |       h24d9097_0         2.2 MB
#     sqlite-3.53.2              |       h795bf6d_0         1.2 MB
#     stack_data-0.6.3           |   py39h06a4308_0          54 KB
#     tabulate-0.9.0             |   py39h06a4308_0          52 KB
#     tbb-2022.3.0               |       h698db13_0         181 KB
#     tbb-devel-2022.3.0         |       h698db13_0         1.1 MB
#     terminado-0.18.1           |   py39h06a4308_0          28 KB
#     tinycss2-1.4.0             |   py39h06a4308_0          96 KB
#     tk-8.6.15                  |       h54e0aa7_0         3.4 MB
#     tomli-2.2.1                |   py39h06a4308_0          29 KB
#     tornado-6.5.1              |   py39h5eee18b_0         667 KB
#     tqdm-4.67.1                |   py39h2f386ee_0         133 KB
#     traitlets-5.14.3           |   py39h06a4308_0         179 KB
#     typer-0.17.4               |   py39h06a4308_0         122 KB
#     typing-extensions-4.15.0   |   py39h06a4308_0          11 KB
#     typing-inspection-0.4.2    |   py39h06a4308_0          27 KB
#     typing_extensions-4.15.0   |   py39h06a4308_0          79 KB
#     tzdata-2026c               |       he532380_0         117 KB
#     ujson-5.10.0               |   py39h6a678d5_1         141 KB
#     urllib3-2.5.0              |   py39h06a4308_0         305 KB
#     wcwidth-0.2.13             |   py39h06a4308_0          70 KB
#     websocket-client-1.8.0     |   py39h06a4308_0          89 KB
#     wheel-0.45.1               |   py39h06a4308_0         114 KB
#     widgetsnbextension-4.0.14  |   py39h06a4308_0         867 KB
#     xcb-util-0.4.1             |       h5eee18b_2          19 KB
#     xcb-util-cursor-0.1.5      |       h5eee18b_0          19 KB
#     xcb-util-image-0.4.0       |       h5eee18b_2          23 KB
#     xcb-util-keysyms-0.4.1     |       h5eee18b_0          13 KB
#     xcb-util-renderutil-0.3.10 |       h5eee18b_0          16 KB
#     xcb-util-wm-0.4.2          |       h5eee18b_0          55 KB
#     xkeyboard-config-2.44      |       h382ed1a_1         887 KB
#     xorg-libice-1.1.2          |       h9b100fa_0          57 KB
#     xorg-libsm-1.2.6           |       h9b100fa_0          26 KB
#     xorg-libx11-1.8.12         |       h9b100fa_1         895 KB
#     xorg-libxau-1.0.12         |       h9b100fa_0          13 KB
#     xorg-libxcomposite-0.4.6   |       h9b100fa_2          12 KB
#     xorg-libxdamage-1.1.6      |       h9b100fa_0          12 KB
#     xorg-libxdmcp-1.1.5        |       h9b100fa_0          19 KB
#     xorg-libxext-1.3.6         |       h9b100fa_0          49 KB
#     xorg-libxfixes-6.0.1       |       h9b100fa_0          18 KB
#     xorg-libxi-1.8.2           |       h9b100fa_0          46 KB
#     xorg-libxrandr-1.5.4       |       h9b100fa_0          28 KB
#     xorg-libxrender-0.9.12     |       h9b100fa_0          31 KB
#     xorg-libxshmfence-1.3.3    |       h9b100fa_0          11 KB
#     xorg-libxtst-1.2.5         |       h9b100fa_3          31 KB
#     xorg-libxxf86vm-1.1.6      |       h9b100fa_0          16 KB
#     xorg-xorgproto-2024.1      |       h47b2149_2         550 KB
#     xz-5.8.2                   |       h448239c_0         621 KB
#     yaml-0.2.5                 |       h591646f_1          74 KB
#     yaml-cpp-0.8.0             |       h6a678d5_1         607 KB
#     zeromq-4.3.5               |       hf801bfb_2         338 KB
#     zipp-3.21.0                |   py39h06a4308_0          26 KB
#     zlib-1.3.2                 |       h47b2149_0          92 KB
#     zstandard-0.24.0           |   py39h3d778a8_0         396 KB
#     zstd-1.5.7                 |       h11fc155_0         608 KB
#     ------------------------------------------------------------
#                                            Total:       550.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           pkgs/main/linux-64::alsa-lib-1.2.15.3-h47b2149_0 None
#   anaconda-anon-usa~ pkgs/main/noarch::anaconda-anon-usage-0.8.1-pyhb46e38b_100 None
#   anaconda-auth      pkgs/main/linux-64::anaconda-auth-0.10.0-py39h06a4308_1 None
#   anaconda-cli-base  pkgs/main/linux-64::anaconda-cli-base-0.5.4-py39h06a4308_0 None
#   annotated-types    pkgs/main/linux-64::annotated-types-0.6.0-py39h06a4308_1 None
#   aom                pkgs/main/linux-64::aom-3.13.2-h664349e_0 None
#   archspec           pkgs/main/noarch::archspec-0.2.5-pyhd3eb1b0_0 None
#   asttokens          pkgs/main/linux-64::asttokens-3.0.0-py39h06a4308_0 None
#   async-lru          pkgs/main/linux-64::async-lru-2.0.5-py39h06a4308_0 None
#   backports.tarfile  pkgs/main/linux-64::backports.tarfile-1.2.0-py39h06a4308_0 None
#   boltons            pkgs/main/linux-64::boltons-25.0.0-py39h06a4308_0 None
#   brotlicffi         pkgs/main/linux-64::brotlicffi-1.0.9.2-py39hbdd6827_2 None
#   cairo              pkgs/main/linux-64::cairo-1.18.4-h44eff21_0 None
#   comm               pkgs/main/linux-64::comm-0.2.1-py39h06a4308_0 None
#   conda-index        pkgs/main/linux-64::conda-index-0.7.0-py39h06a4308_0 None
#   conda-libmamba-so~ pkgs/main/noarch::conda-libmamba-solver-25.4.0-pyhdf14ebd_1 None
#   conda-package-str~ pkgs/main/linux-64::conda-package-streaming-0.12.0-py39h06a4308_0 None
#   cpp-expected       pkgs/main/linux-64::cpp-expected-1.1.0-hdb19cb5_0 None
#   cyrus-sasl         pkgs/main/linux-64::cyrus-sasl-2.1.28-h1110e0f_3 None
#   dav1d              pkgs/main/linux-64::dav1d-1.5.3-h12c9f22_1 None
#   distro             pkgs/main/linux-64::distro-1.9.0-py39h06a4308_0 None
#   evalidate          pkgs/main/linux-64::evalidate-2.0.3-py39h06a4308_0 None
#   exceptiongroup     pkgs/main/linux-64::exceptiongroup-1.2.0-py39h06a4308_0 None
#   executing          pkgs/main/linux-64::executing-2.2.1-py39h06a4308_0 None
#   fmt                pkgs/main/linux-64::fmt-11.2.0-hca5f364_0 None
#   fribidi            pkgs/main/linux-64::fribidi-1.0.16-h10f3c28_1 None
#   frozendict         pkgs/main/linux-64::frozendict-2.4.6-py39hee96239_0 None
#   gettext            pkgs/main/linux-64::gettext-0.25.1-h92eb808_0 None
#   gettext-tools      pkgs/main/linux-64::gettext-tools-0.25.1-h6a67909_0 None
#   graphite2          pkgs/main/linux-64::graphite2-1.3.15-h9ba177b_0 None
#   h11                pkgs/main/linux-64::h11-0.16.0-py39h06a4308_0 None
#   harfbuzz           pkgs/main/linux-64::harfbuzz-10.2.0-hdfddeaa_1 None
#   httpcore           pkgs/main/linux-64::httpcore-1.0.9-py39h06a4308_0 None
#   httpx              pkgs/main/linux-64::httpx-0.28.1-py39h06a4308_1 None
#   jansson            pkgs/main/linux-64::jansson-2.15.0-hbcba0ee_0 None
#   jaraco.classes     pkgs/main/linux-64::jaraco.classes-3.4.0-py39h06a4308_0 None
#   jaraco.context     pkgs/main/linux-64::jaraco.context-6.0.0-py39h06a4308_0 None
#   jaraco.functools   pkgs/main/linux-64::jaraco.functools-4.1.0-py39h06a4308_0 None
#   jsonpatch          pkgs/main/linux-64::jsonpatch-1.33-py39h06a4308_1 None
#   jsonpointer        pkgs/main/linux-64::jsonpointer-3.0.0-py39h06a4308_0 None
#   jsonschema-specif~ pkgs/main/linux-64::jsonschema-specifications-2023.7.1-py39h06a4308_0 None
#   jupyter-lsp        pkgs/main/linux-64::jupyter-lsp-2.2.5-py39h06a4308_0 None
#   jupyter_events     pkgs/main/linux-64::jupyter_events-0.12.0-py39h06a4308_0 None
#   jupyter_server_te~ pkgs/main/linux-64::jupyter_server_terminals-0.5.3-py39h06a4308_0 None
#   libabseil          pkgs/main/linux-64::libabseil-20260526.0-cxx17_h724b069_0 None
#   libasprintf        pkgs/main/linux-64::libasprintf-0.25.1-hf2ab22a_0 None
#   libasprintf-devel  pkgs/main/linux-64::libasprintf-devel-0.25.1-hf2ab22a_0 None
#   libavif            pkgs/main/linux-64::libavif-1.3.0-h2b90b00_1 None
#   libclang13         pkgs/main/linux-64::libclang13-22.1.2-default_hc2d2b39_2 None
#   libcups            pkgs/main/linux-64::libcups-2.4.19-h23114ae_0 None
#   libdrm             pkgs/main/linux-64::libdrm-2.4.134-h9c74679_0 None
#   libegl             pkgs/main/linux-64::libegl-1.7.0-h5eee18b_2 None
#   libexpat           pkgs/main/linux-64::libexpat-2.8.2-h7354ed3_1 None
#   libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_8 None
#   libgettextpo       pkgs/main/linux-64::libgettextpo-0.25.1-hf2ab22a_0 None
#   libgettextpo-devel pkgs/main/linux-64::libgettextpo-devel-0.25.1-hf2ab22a_0 None
#   libgl              pkgs/main/linux-64::libgl-1.7.0-h5eee18b_2 None
#   libglib            pkgs/main/linux-64::libglib-2.88.3-ha16e27a_0 None
#   libglvnd           pkgs/main/linux-64::libglvnd-1.7.0-h5eee18b_2 None
#   libglx             pkgs/main/linux-64::libglx-1.7.0-h5eee18b_2 None
#   libhwloc           pkgs/main/linux-64::libhwloc-2.12.1-default_hf1bbc79_1000 None
#   libiconv           pkgs/main/linux-64::libiconv-1.18-h75a1612_0 None
#   libkrb5            pkgs/main/linux-64::libkrb5-1.21.3-h520c7b4_4 None
#   libllvm22          pkgs/main/linux-64::libllvm22-22.1.2-hfb1d434_0 None
#   libmamba           pkgs/main/linux-64::libmamba-2.3.2-h4368100_0 None
#   libmambapy         pkgs/main/linux-64::libmambapy-2.3.2-py39hea2f153_0 None
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0 None
#   libopenjpeg        pkgs/main/linux-64::libopenjpeg-2.5.4-hee96239_1 None
#   libopus            pkgs/main/linux-64::libopus-1.6.1-h9f10d21_0 None
#   libpciaccess       pkgs/main/linux-64::libpciaccess-0.18-h5eee18b_0 None
#   libre2-11          pkgs/main/linux-64::libre2-11-2025.11.05-h7354ed3_2 None
#   libsolv            pkgs/main/linux-64::libsolv-0.7.39-h04d0c11_0 None
#   libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_8 None
#   libvpx             pkgs/main/linux-64::libvpx-1.15.2-h4cb591d_0 None
#   libxkbfile         pkgs/main/linux-64::libxkbfile-1.1.0-hf54ef8a_2 None
#   libzlib            pkgs/main/linux-64::libzlib-1.3.2-h47b2149_0 None
#   lmdb               pkgs/main/linux-64::lmdb-1.0.0-hfe55579_0 None
#   markdown-it-py     pkgs/main/linux-64::markdown-it-py-2.2.0-py39h06a4308_1 None
#   mbedtls            pkgs/main/linux-64::mbedtls-3.5.1-h6a678d5_1 None
#   mdurl              pkgs/main/linux-64::mdurl-0.1.2-py39h06a4308_0 None
#   menuinst           pkgs/main/linux-64::menuinst-2.4.1-py39h06a4308_0 None
#   mesalib            pkgs/main/linux-64::mesalib-25.1.5-h3583ad3_5 None
#   more-itertools     pkgs/main/linux-64::more-itertools-10.8.0-py39h06a4308_0 None
#   mysql-common       pkgs/main/linux-64::mysql-common-9.3.0-h9e076cb_6 None
#   mysql-libs         pkgs/main/linux-64::mysql-libs-9.3.0-he5ffe59_6 None
#   nbconvert-core     pkgs/main/linux-64::nbconvert-core-7.16.6-py39h06a4308_0 None
#   nlohmann_json      pkgs/main/linux-64::nlohmann_json-3.11.2-h6a678d5_0 None
#   notebook-shim      pkgs/main/linux-64::notebook-shim-0.2.4-py39h06a4308_0 None
#   openldap           pkgs/main/linux-64::openldap-2.6.12-h007892f_1 None
#   overrides          pkgs/main/linux-64::overrides-7.4.0-py39h06a4308_0 None
#   pcre2              pkgs/main/linux-64::pcre2-10.46-hf426167_0 None
#   pixman             pkgs/main/linux-64::pixman-0.46.4-h86ba9f7_1 None
#   pkce               pkgs/main/linux-64::pkce-1.0.3-py39h06a4308_0 None
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h47b2149_2 None
#   pure_eval          pkgs/main/linux-64::pure_eval-0.2.3-py39h06a4308_0 None
#   pybind11-abi       pkgs/main/noarch::pybind11-abi-4-hd3eb1b0_1 None
#   pydantic           pkgs/main/linux-64::pydantic-2.12.2-py39h06a4308_0 None
#   pydantic-core      pkgs/main/linux-64::pydantic-core-2.41.4-py39h498d7c9_0 None
#   pydantic-settings  pkgs/main/linux-64::pydantic-settings-2.10.1-py39h06a4308_0 None
#   pyside6            pkgs/main/linux-64::pyside6-6.9.2-py39h2ddcaae_0 None
#   python-dotenv      pkgs/main/linux-64::python-dotenv-1.1.0-py39h06a4308_0 None
#   python-json-logger pkgs/main/linux-64::python-json-logger-3.2.1-py39h06a4308_0 None
#   qtbase             pkgs/main/linux-64::qtbase-6.9.2-hd13baf8_5 None
#   qtdeclarative      pkgs/main/linux-64::qtdeclarative-6.9.2-h55666de_1 None
#   qtshadertools      pkgs/main/linux-64::qtshadertools-6.9.2-hbdd6827_1 None
#   qtsvg              pkgs/main/linux-64::qtsvg-6.9.2-h75a08ff_1 None
#   qttools            pkgs/main/linux-64::qttools-6.9.2-hc856bc8_1 None
#   qtwebchannel       pkgs/main/linux-64::qtwebchannel-6.9.2-hbdd6827_1 None
#   qtwebengine        pkgs/main/linux-64::qtwebengine-6.9.2-hbdb40ff_1 None
#   qtwebsockets       pkgs/main/linux-64::qtwebsockets-6.9.2-hbdd6827_1 None
#   re2                pkgs/main/linux-64::re2-2025.11.05-h71b5c5c_2 None
#   readchar           pkgs/main/linux-64::readchar-4.2.1-py39h06a4308_0 None
#   referencing        pkgs/main/linux-64::referencing-0.30.2-py39h06a4308_0 None
#   reproc             pkgs/main/linux-64::reproc-14.2.7-h7bdf020_0 None
#   reproc-cpp         pkgs/main/linux-64::reproc-cpp-14.2.7-h7bdf020_0 None
#   requests-toolbelt  pkgs/main/linux-64::requests-toolbelt-1.0.0-py39h06a4308_0 None
#   rfc3339-validator  pkgs/main/linux-64::rfc3339-validator-0.1.4-py39h06a4308_0 None
#   rfc3986-validator  pkgs/main/linux-64::rfc3986-validator-0.1.1-py39h06a4308_0 None
#   rich               pkgs/main/linux-64::rich-14.2.0-py39h06a4308_0 None
#   rpds-py            pkgs/main/linux-64::rpds-py-0.22.3-py39h4aa5aa6_0 None
#   ruamel.yaml        pkgs/main/linux-64::ruamel.yaml-0.18.10-py39h5eee18b_0 None
#   ruamel.yaml.clib   pkgs/main/linux-64::ruamel.yaml.clib-0.2.12-py39h5eee18b_0 None
#   semver             pkgs/main/linux-64::semver-3.0.4-py39h06a4308_0 None
#   shellingham        pkgs/main/linux-64::shellingham-1.5.4-py39h06a4308_0 None
#   simdjson           pkgs/main/linux-64::simdjson-3.10.1-hdb19cb5_0 None
#   spirv-tools        pkgs/main/linux-64::spirv-tools-2026.1-h24d9097_0 None
#   stack_data         pkgs/main/linux-64::stack_data-0.6.3-py39h06a4308_0 None
#   tbb-devel          pkgs/main/linux-64::tbb-devel-2022.3.0-h698db13_0 None
#   tinycss2           pkgs/main/linux-64::tinycss2-1.4.0-py39h06a4308_0 None
#   typer              pkgs/main/linux-64::typer-0.17.4-py39h06a4308_0 None
#   typing-inspection  pkgs/main/linux-64::typing-inspection-0.4.2-py39h06a4308_0 None
#   xcb-util           pkgs/main/linux-64::xcb-util-0.4.1-h5eee18b_2 None
#   xcb-util-cursor    pkgs/main/linux-64::xcb-util-cursor-0.1.5-h5eee18b_0 None
#   xcb-util-image     pkgs/main/linux-64::xcb-util-image-0.4.0-h5eee18b_2 None
#   xcb-util-keysyms   pkgs/main/linux-64::xcb-util-keysyms-0.4.1-h5eee18b_0 None
#   xcb-util-renderut~ pkgs/main/linux-64::xcb-util-renderutil-0.3.10-h5eee18b_0 None
#   xcb-util-wm        pkgs/main/linux-64::xcb-util-wm-0.4.2-h5eee18b_0 None
#   xkeyboard-config   pkgs/main/linux-64::xkeyboard-config-2.44-h382ed1a_1 None
#   xorg-libice        pkgs/main/linux-64::xorg-libice-1.1.2-h9b100fa_0 None
#   xorg-libsm         pkgs/main/linux-64::xorg-libsm-1.2.6-h9b100fa_0 None
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1 None
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0 None
#   xorg-libxcomposite pkgs/main/linux-64::xorg-libxcomposite-0.4.6-h9b100fa_2 None
#   xorg-libxdamage    pkgs/main/linux-64::xorg-libxdamage-1.1.6-h9b100fa_0 None
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0 None
#   xorg-libxext       pkgs/main/linux-64::xorg-libxext-1.3.6-h9b100fa_0 None
#   xorg-libxfixes     pkgs/main/linux-64::xorg-libxfixes-6.0.1-h9b100fa_0 None
#   xorg-libxi         pkgs/main/linux-64::xorg-libxi-1.8.2-h9b100fa_0 None
#   xorg-libxrandr     pkgs/main/linux-64::xorg-libxrandr-1.5.4-h9b100fa_0 None
#   xorg-libxrender    pkgs/main/linux-64::xorg-libxrender-0.9.12-h9b100fa_0 None
#   xorg-libxshmfence  pkgs/main/linux-64::xorg-libxshmfence-1.3.3-h9b100fa_0 None
#   xorg-libxtst       pkgs/main/linux-64::xorg-libxtst-1.2.5-h9b100fa_3 None
#   xorg-libxxf86vm    pkgs/main/linux-64::xorg-libxxf86vm-1.1.6-h9b100fa_0 None
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h47b2149_2 None
#   yaml-cpp           pkgs/main/linux-64::yaml-cpp-0.8.0-h6a678d5_1 None
#   zstandard          pkgs/main/linux-64::zstandard-0.24.0-py39h3d778a8_0 None
#
# The following packages will be REMOVED:
#
#   alabaster-0.7.12-pyhd3eb1b0_0
#   anaconda-2022.10-py39_0
#   anaconda-project-0.11.1-py39h06a4308_0
#   appdirs-1.4.4-pyhd3eb1b0_0
#   arrow-1.2.2-pyhd3eb1b0_0
#   astroid-2.11.7-py39h06a4308_0
#   astropy-5.1-py39h7deecbd_0
#   atomicwrites-1.4.0-py_0
#   automat-20.2.0-py_0
#   autopep8-1.6.0-pyhd3eb1b0_1
#   bcrypt-3.2.0-py39h5eee18b_1
#   binaryornot-0.4.4-pyhd3eb1b0_1
#   bitarray-2.5.1-py39h5eee18b_0
#   bkcharts-0.2-py39h06a4308_1
#   black-22.6.0-py39h06a4308_0
#   blosc-1.21.0-h4ff587b_1
#   bokeh-2.4.3-py39h06a4308_0
#   boto3-1.24.28-py39h06a4308_0
#   botocore-1.27.28-py39h06a4308_0
#   bottleneck-1.3.5-py39h7deecbd_0
#   brotli-1.0.9-h5eee18b_7
#   brotli-bin-1.0.9-h5eee18b_7
#   brotlipy-0.7.0-py39h27cfd23_1003
#   brunsli-0.1-h2531618_0
#   cfitsio-3.470-h5893167_7
#   charls-2.2.0-h2531618_0
#   cloudpickle-2.0.0-pyhd3eb1b0_0
#   clyent-1.2.2-py39h06a4308_1
#   colorama-0.4.5-py39h06a4308_0
#   colorcet-3.0.0-py39h06a4308_0
#   conda-content-trust-0.1.3-py39h06a4308_0
#   conda-pack-0.6.0-pyhd3eb1b0_0
#   conda-token-0.4.0-pyhd3eb1b0_0
#   constantly-15.1.0-pyh2b92418_0
#   cookiecutter-1.7.3-pyhd3eb1b0_0
#   cssselect-1.1.0-pyhd3eb1b0_0
#   curl-7.84.0-h5eee18b_0
#   cycler-0.11.0-pyhd3eb1b0_0
#   cython-0.29.32-py39h6a678d5_0
#   cytoolz-0.11.0-py39h27cfd23_0
#   daal4py-2021.6.0-py39h79cecc1_1
#   dal-2021.6.0-hdb19cb5_916
#   dask-2022.7.0-py39h06a4308_0
#   dask-core-2022.7.0-py39h06a4308_0
#   dataclasses-0.8-pyh6d0b6a4_7
#   datashader-0.14.1-py39h06a4308_0
#   datashape-0.5.4-py39h06a4308_1
#   diff-match-patch-20200713-pyhd3eb1b0_0
#   dill-0.3.4-pyhd3eb1b0_0
#   distributed-2022.7.0-py39h06a4308_0
#   docutils-0.18.1-py39h06a4308_3
#   entrypoints-0.4-py39h06a4308_0
#   et_xmlfile-1.1.0-py39h06a4308_0
#   fftw-3.3.9-h27cfd23_1
#   flake8-4.0.1-pyhd3eb1b0_1
#   flask-1.1.2-pyhd3eb1b0_0
#   fonttools-4.25.0-pyhd3eb1b0_0
#   fsspec-2022.7.1-py39h06a4308_0
#   gensim-4.1.2-py39h295c915_0
#   giflib-5.2.1-h7b6447c_0
#   glib-2.69.1-h4ff587b_1
#   glob2-0.7-pyhd3eb1b0_0
#   gmp-6.2.1-h295c915_3
#   gmpy2-2.1.2-py39heeb90bb_0
#   greenlet-1.1.1-py39h295c915_0
#   gst-plugins-base-1.14.0-h8213a91_2
#   gstreamer-1.14.0-h28cd5cc_2
#   h5py-3.7.0-py39h737f45e_0
#   hdf5-1.10.6-h3ffc7dd_1
#   heapdict-1.0.1-pyhd3eb1b0_0
#   holoviews-1.15.0-py39h06a4308_0
#   hvplot-0.8.0-py39h06a4308_0
#   hyperlink-21.0.0-pyhd3eb1b0_0
#   imagecodecs-2021.8.26-py39hf0132c2_1
#   imageio-2.19.3-py39h06a4308_0
#   imagesize-1.4.1-py39h06a4308_0
#   incremental-21.3.0-pyhd3eb1b0_0
#   inflection-0.5.1-py39h06a4308_0
#   iniconfig-1.1.1-pyhd3eb1b0_0
#   intake-0.6.5-pyhd3eb1b0_0
#   intervaltree-3.1.0-pyhd3eb1b0_0
#   ipython_genutils-0.2.0-pyhd3eb1b0_1
#   isort-5.9.3-pyhd3eb1b0_0
#   itemadapter-0.3.0-pyhd3eb1b0_0
#   itemloaders-1.0.4-pyhd3eb1b0_1
#   itsdangerous-2.0.1-pyhd3eb1b0_0
#   jdcal-1.4.1-pyhd3eb1b0_0
#   jellyfish-0.9.0-py39h7f8727e_0
#   jinja2-time-0.2.0-pyhd3eb1b0_3
#   jmespath-0.10.0-pyhd3eb1b0_0
#   joblib-1.1.0-pyhd3eb1b0_0
#   jq-1.6-h27cfd23_1000
#   jupyter-1.0.0-py39h06a4308_8
#   jupyter_console-6.4.3-pyhd3eb1b0_0
#   jxrlib-1.1-h7b6447c_2
#   kiwisolver-1.4.2-py39h295c915_0
#   krb5-1.19.2-hac12032_0
#   lazy-object-proxy-1.6.0-py39h27cfd23_0
#   libaec-1.0.4-he6710b0_1
#   libbrotlicommon-1.0.9-h5eee18b_7
#   libbrotlidec-1.0.9-h5eee18b_7
#   libbrotlienc-1.0.9-h5eee18b_7
#   libclang-10.0.1-default_hb85057a_2
#   libedit-3.1.20210910-h7f8727e_0
#   libgfortran-ng-11.2.0-h00389a5_1
#   libgfortran5-11.2.0-h1234567_1
#   libgomp-11.2.0-h1234567_1
#   libllvm10-10.0.1-hbcb73fb_5
#   libllvm11-11.1.0-h9e868ea_5
#   libspatialindex-1.9.3-h2531618_0
#   libwebp-1.2.2-h55f646e_0
#   libzopfli-1.0.3-he6710b0_0
#   llvmlite-0.38.0-py39h4ff587b_0
#   locket-1.0.0-py39h06a4308_0
#   lxml-4.9.1-py39h1edc446_0
#   lz4-3.1.3-py39h27cfd23_0
#   lzo-2.10-h7b6447c_2
#   markdown-3.3.4-py39h06a4308_0
#   matplotlib-3.5.2-py39h06a4308_0
#   matplotlib-base-3.5.2-py39hf590b9c_0
#   mccabe-0.7.0-pyhd3eb1b0_0
#   mock-4.0.3-pyhd3eb1b0_0
#   mpc-1.1.0-h10f8cd9_1
#   mpfr-4.0.2-hb69a4c5_1
#   mpi-1.0-mpich
#   mpich-3.3.2-external_0
#   mpmath-1.2.1-py39h06a4308_0
#   multipledispatch-0.6.0-py39h06a4308_0
#   munkres-1.1.4-py_0
#   mypy_extensions-0.4.3-py39h06a4308_1
#   nbclassic-0.3.5-pyhd3eb1b0_0
#   nbconvert-6.4.4-py39h06a4308_0
#   networkx-2.8.4-py39h06a4308_0
#   nltk-3.7-pyhd3eb1b0_0
#   nose-1.3.7-pyhd3eb1b0_1008
#   notebook-6.4.12-py39h06a4308_0
#   numba-0.55.1-py39h51133e4_0
#   numexpr-2.8.3-py39h807cd23_0
#   numpydoc-1.4.0-py39h06a4308_0
#   olefile-0.46-pyhd3eb1b0_0
#   oniguruma-6.9.7.1-h27cfd23_0
#   openpyxl-3.0.10-py39h5eee18b_0
#   pandas-1.4.4-py39h6a678d5_0
#   panel-0.13.1-py39h06a4308_0
#   param-1.12.0-pyhd3eb1b0_0
#   parsel-1.6.0-py39h06a4308_0
#   partd-1.2.0-pyhd3eb1b0_1
#   pathlib-1.0.1-pyhd3eb1b0_1
#   pathspec-0.9.0-py39h06a4308_0
#   patsy-0.5.2-py39h06a4308_1
#   pcre-8.45-h295c915_0
#   pep8-1.7.1-py39h06a4308_1
#   plotly-5.9.0-py39h06a4308_0
#   ply-3.11-py39h06a4308_0
#   poyo-0.5.0-pyhd3eb1b0_0
#   prompt_toolkit-3.0.20-hd3eb1b0_0
#   protego-0.1.16-py_0
#   py-1.11.0-pyhd3eb1b0_0
#   pyasn1-0.4.8-pyhd3eb1b0_0
#   pyasn1-modules-0.2.8-py_0
#   pycodestyle-2.8.0-pyhd3eb1b0_0
#   pyct-0.4.8-py39h06a4308_1
#   pycurl-7.45.1-py39h8f2d780_0
#   pydispatcher-2.0.5-py39h06a4308_2
#   pydocstyle-6.1.1-pyhd3eb1b0_0
#   pyerfa-2.0.0-py39h27cfd23_0
#   pyflakes-2.4.0-pyhd3eb1b0_0
#   pyhamcrest-2.0.2-pyhd3eb1b0_2
#   pylint-2.14.5-py39h06a4308_0
#   pyls-spyder-0.4.0-pyhd3eb1b0_0
#   pyodbc-4.0.34-py39h6a678d5_0
#   pyopenssl-22.0.0-pyhd3eb1b0_0
#   pyparsing-3.0.9-py39h06a4308_0
#   pyqt-5.15.7-py39h6a678d5_1
#   pyqt5-sip-12.11.0-py39h6a678d5_1
#   pyqtwebengine-5.15.7-py39h6a678d5_1
#   pyrsistent-0.18.0-py39heee7806_0
#   pytables-3.6.1-py39h77479fe_1
#   pytest-7.1.2-py39h06a4308_0
#   python-lsp-black-1.2.1-py39h06a4308_0
#   python-lsp-jsonrpc-1.0.0-pyhd3eb1b0_0
#   python-lsp-server-1.5.0-py39h06a4308_0
#   python-slugify-5.0.2-pyhd3eb1b0_0
#   python-snappy-0.6.0-py39h2531618_3
#   pyviz_comms-2.0.2-pyhd3eb1b0_0
#   pywavelets-1.3.0-py39h7f8727e_0
#   pyxdg-0.27-pyhd3eb1b0_0
#   qdarkstyle-3.0.2-pyhd3eb1b0_0
#   qstylizer-0.1.10-pyhd3eb1b0_0
#   qt-5.15.9-h06a4308_0
#   qt-main-5.15.2-h327a75a_7
#   qt-webengine-5.15.9-hd2b0992_4
#   qtawesome-1.0.3-pyhd3eb1b0_0
#   qtconsole-5.3.2-py39h06a4308_0
#   qtwebkit-5.212-h4eab89a_4
#   queuelib-1.5.0-py39h06a4308_0
#   regex-2022.7.9-py39h5eee18b_0
#   requests-file-1.5.1-pyhd3eb1b0_0
#   ripgrep-13.0.0-hbdeaff8_0
#   rope-0.22.0-pyhd3eb1b0_0
#   rtree-0.9.7-py39h06a4308_1
#   ruamel_yaml-0.15.100-py39h27cfd23_0
#   s3transfer-0.6.0-py39h06a4308_0
#   scikit-image-0.19.2-py39h51133e4_0
#   scikit-learn-1.0.2-py39h51133e4_1
#   scikit-learn-intelex-2021.6.0-py39h06a4308_0
#   scipy-1.9.1-py39h14f4228_0
#   scrapy-2.6.2-py39h06a4308_0
#   seaborn-0.11.2-pyhd3eb1b0_0
#   service_identity-18.1.0-pyhd3eb1b0_1
#   sip-6.6.2-py39h6a678d5_0
#   smart_open-5.2.1-py39h06a4308_0
#   snowballstemmer-2.2.0-pyhd3eb1b0_0
#   sortedcollections-2.1.0-pyhd3eb1b0_0
#   sortedcontainers-2.4.0-pyhd3eb1b0_0
#   sphinx-5.0.2-py39h06a4308_0
#   sphinxcontrib-applehelp-1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-devhelp-1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-htmlhelp-2.0.0-pyhd3eb1b0_0
#   sphinxcontrib-jsmath-1.0.1-pyhd3eb1b0_0
#   sphinxcontrib-qthelp-1.0.3-pyhd3eb1b0_0
#   sphinxcontrib-serializinghtml-1.1.5-pyhd3eb1b0_0
#   spyder-5.3.3-py39h06a4308_0
#   spyder-kernels-2.3.3-py39h06a4308_0
#   sqlalchemy-1.4.39-py39h5eee18b_0
#   statsmodels-0.13.2-py39h7f8727e_0
#   sympy-1.10.1-py39h06a4308_0
#   tbb4py-2021.6.0-py39hdb19cb5_0
#   tblib-1.7.0-pyhd3eb1b0_0
#   tenacity-8.0.1-py39h06a4308_1
#   testpath-0.6.0-py39h06a4308_0
#   text-unidecode-1.3-pyhd3eb1b0_0
#   textdistance-4.2.1-pyhd3eb1b0_0
#   threadpoolctl-2.2.0-pyh0d69192_0
#   three-merge-0.1.1-pyhd3eb1b0_0
#   tifffile-2021.7.2-pyhd3eb1b0_2
#   tinycss-0.4-pyhd3eb1b0_1002
#   tldextract-3.2.0-pyhd3eb1b0_0
#   toml-0.10.2-pyhd3eb1b0_0
#   tomlkit-0.11.1-py39h06a4308_0
#   toolz-0.11.2-pyhd3eb1b0_0
#   twisted-22.2.0-py39h5eee18b_1
#   unidecode-1.2.0-pyhd3eb1b0_0
#   unixodbc-2.3.11-h5eee18b_0
#   w3lib-1.21.0-pyhd3eb1b0_0
#   watchdog-2.1.6-py39h06a4308_0
#   werkzeug-2.0.3-pyhd3eb1b0_0
#   wget-1.21.3-h0b77cf5_0
#   whatthepatch-1.0.2-py39h06a4308_0
#   wrapt-1.14.1-py39h5eee18b_0
#   wurlitzer-3.0.2-py39h06a4308_0
#   xarray-0.20.1-pyhd3eb1b0_1
#   xlrd-2.0.1-pyhd3eb1b0_0
#   xlsxwriter-3.0.3-pyhd3eb1b0_0
#   yapf-0.31.0-pyhd3eb1b0_0
#   zfp-0.5.5-h295c915_6
#   zict-2.1.0-py39h06a4308_0
#   zope-1.0-py39h06a4308_1
#   zope.interface-5.4.0-py39h7f8727e_0
#
# The following packages will be UPDATED:
#
#   _openmp_mutex                                   5.1-1_gnu --> 5.1-52_gnu None
#   anaconda-client                     1.11.0-py39h06a4308_0 --> 1.13.1-py39h06a4308_0 None
#   anaconda-navigator                   2.3.1-py39h06a4308_0 --> 2.7.0-py39h06a4308_1 None
#   anyio                                3.5.0-py39h06a4308_0 --> 4.10.0-py39h06a4308_0 None
#   argon2-cffi-bindi~                  21.2.0-py39h7f8727e_0 --> 25.1.0-py39hee96239_0 None
#   attrs              pkgs/main/noarch::attrs-21.4.0-pyhd3e~ --> pkgs/main/linux-64::attrs-25.4.0-py39h06a4308_1 None
#   babel              pkgs/main/noarch::babel-2.9.1-pyhd3eb~ --> pkgs/main/linux-64::babel-2.16.0-py39h06a4308_0 None
#   backcall                               0.2.0-pyhd3eb1b0_0 --> 0.2.0-pyhd3eb1b0_1 None
#   backports                                1.1-pyhd3eb1b0_0 --> 1.1-pyhd3eb1b0_1 None
#   beautifulsoup4                      4.11.1-py39h06a4308_0 --> 4.13.5-py39h06a4308_0 None
#   bleach             pkgs/main/noarch::bleach-4.1.0-pyhd3e~ --> pkgs/main/linux-64::bleach-6.2.0-py39h06a4308_0 None
#   bzip2                                    1.0.8-h7b6447c_0 --> 1.0.8-h5eee18b_6 None
#   c-ares                                  1.18.1-h7f8727e_0 --> 1.34.7-hd44998d_0 None
#   ca-certificates                     2022.07.19-h06a4308_0 --> 2026.7.16-h06a4308_0 None
#   certifi                          2022.9.14-py39h06a4308_0 --> 2025.10.5-py39h06a4308_0 None
#   cffi                                1.15.1-py39h74dc2b5_0 --> 2.0.0-py39h4eded50_0 None
#   chardet                           4.0.0-py39h06a4308_1003 --> 5.2.0-py39h06a4308_0 None
#   charset-normalizer pkgs/main/noarch::charset-normalizer-~ --> pkgs/main/linux-64::charset-normalizer-3.4.4-py39h06a4308_0 None
#   click                                8.0.4-py39h06a4308_0 --> 8.1.8-py39h06a4308_0 None
#   conda                               22.9.0-py39h06a4308_0 --> 25.9.1-py39h06a4308_0 None
#   conda-build                         3.22.0-py39h06a4308_0 --> 25.9.0-py39h76456e7_0 None
#   conda-package-han~                   1.9.0-py39h5eee18b_0 --> 2.4.0-py39h06a4308_0 None
#   conda-repo-cli                      1.0.20-py39h06a4308_0 --> 1.0.173-py39h06a4308_0 None
#   cryptography                        37.0.1-py39h9ce1e76_0 --> 46.0.2-py39h498d7c9_0 None
#   dbus                                   1.13.18-hb2f20db_0 --> 1.16.2-h5bd4931_0 None
#   debugpy                              1.5.1-py39h295c915_0 --> 1.8.16-py39hbdd6827_0 None
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyh~ --> pkgs/main/linux-64::decorator-5.2.1-py39h06a4308_0 None
#   expat                                    2.4.9-h6a678d5_0 --> 2.8.2-h7354ed3_1 None
#   filelock           pkgs/main/noarch::filelock-3.6.0-pyhd~ --> pkgs/main/linux-64::filelock-3.17.0-py39h06a4308_0 None
#   fontconfig                              2.13.1-h6c09931_0 --> 2.15.0-h2c49b7f_0 None
#   freetype                                2.11.0-h70c0345_0 --> 2.14.1-hf5b9546_0 None
#   future                              0.18.2-py39h06a4308_1 --> 1.0.0-py39h06a4308_0 None
#   icu                                       58.2-he6710b0_3 --> 73.1-h6a678d5_0 None
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0~ --> pkgs/main/linux-64::idna-3.11-py39h06a4308_0 None
#   importlib-metadata                  4.11.3-py39h06a4308_0 --> 8.5.0-py39h06a4308_0 None
#   importlib_metadata                      4.11.3-hd3eb1b0_0 --> 8.5.0-hd3eb1b0_0 None
#   intel-openmp                       2021.4.0-h06a4308_3561 --> 2025.0.0-h06a4308_1172 None
#   ipykernel                           6.15.2-py39h06a4308_0 --> 6.30.1-py39h06a4308_0 None
#   ipython                             7.31.1-py39h06a4308_1 --> 8.15.0-py39h06a4308_0 None
#   ipywidgets         pkgs/main/noarch::ipywidgets-7.6.5-py~ --> pkgs/main/linux-64::ipywidgets-8.1.7-py39h06a4308_0 None
#   jedi                                0.18.1-py39h06a4308_1 --> 0.19.2-py39h06a4308_0 None
#   jinja2             pkgs/main/noarch::jinja2-2.11.3-pyhd3~ --> pkgs/main/linux-64::jinja2-3.1.6-py39h06a4308_0 None
#   jpeg                                        9e-h7f8727e_0 --> 9f-h5ce9db8_0 None
#   json5              pkgs/main/noarch::json5-0.9.6-pyhd3eb~ --> pkgs/main/linux-64::json5-0.9.25-py39h06a4308_0 None
#   jsonschema                          4.16.0-py39h06a4308_0 --> 4.25.0-py39h06a4308_0 None
#   jupyter_client                       7.3.4-py39h06a4308_0 --> 8.6.3-py39h06a4308_0 None
#   jupyter_core                        4.11.1-py39h06a4308_0 --> 5.8.1-py39h06a4308_0 None
#   jupyter_server                      1.18.1-py39h06a4308_0 --> 2.16.0-py39h06a4308_0 None
#   jupyterlab                           3.4.4-py39h06a4308_0 --> 4.4.7-py39h06a4308_0 None
#   jupyterlab_pygmen~ pkgs/main/noarch::jupyterlab_pygments~ --> pkgs/main/linux-64::jupyterlab_pygments-0.3.0-py39h06a4308_0 None
#   jupyterlab_server  pkgs/main/noarch::jupyterlab_server-2~ --> pkgs/main/linux-64::jupyterlab_server-2.28.0-py39h06a4308_0 None
#   jupyterlab_widgets                     1.0.0-pyhd3eb1b0_1 --> 3.0.16-pyhd3eb1b0_2 None
#   keyring                             23.4.0-py39h06a4308_0 --> 25.6.0-py39h06a4308_0 None
#   lcms2                                     2.12-h3be6417_0 --> 2.19-he283960_0 None
#   ld_impl_linux-64                          2.38-h1181459_1 --> 2.44-h9e0c5a2_3 None
#   lerc                                       3.0-h295c915_0 --> 4.1.0-h7354ed3_2 None
#   libarchive                               3.6.1-hab531cd_0 --> 3.8.2-h3ec8f01_0 None
#   libcurl                                 7.84.0-h91b91d3_0 --> 8.17.0-hc93bc37_0 None
#   libdeflate                                 1.8-h7f8727e_5 --> 1.22-h5eee18b_0 None
#   libevent                                2.1.12-h8f2d780_0 --> 2.1.12-hdbd6064_1 None
#   libffi                                     3.3-he6710b0_2 --> 3.4.8-h06d3fd0_3 None
#   libgcc-ng                               11.2.0-h1234567_1 --> 15.2.0-h166f726_8 None
#   libidn2                                  2.3.2-h7f8727e_0 --> 2.3.8-hf80d704_0 None
#   liblief                                 0.11.5-h295c915_1 --> 0.16.4-h6a678d5_0 None
#   libnghttp2                              1.46.0-hce63b2e_0 --> 1.67.1-h697f920_0 None
#   libpng                                  1.6.37-hbc83047_0 --> 1.6.56-h22898a0_0 None
#   libpq                                     12.9-h16c4e8d_3 --> 17.6-ha51bf15_0 None
#   libsodium                               1.0.18-h7b6447c_0 --> 1.0.21-h83fc4cd_1 None
#   libssh2                                 1.10.0-h8f2d780_0 --> 1.11.1-hfbabe93_1 None
#   libstdcxx-ng                            11.2.0-h1234567_1 --> 15.2.0-hc03a8fd_8 None
#   libtiff                                  4.4.0-hecacb30_0 --> 4.7.1-h029b1ac_0 None
#   libunistring                            0.9.10-h27cfd23_0 --> 1.4.2-h34b0ebb_0 None
# ...
# xorg-libxdmcp-1.1.5  | 19 KB     | ##################################### | 100%
# xcb-util-0.4.1       | 19 KB     | ##################################### | 100%
# tbb-2022.3.0         | 181 KB    | ##################################### | 100%
# soupsieve-2.5        | 69 KB     | ##################################### | 100%
# jupyterlab_widgets-3 | 185 KB    | ##################################### | 100%
# cairo-1.18.4         | 728 KB    | ##################################### | 100%
# libglib-2.88.3       | 3.9 MB    | ##################################### | 100%
# libsolv-0.7.39       | 471 KB    | ##################################### | 100%
# libidn2-2.3.8        | 80 KB     | ##################################### | 100%
# comm-0.2.1           | 14 KB     | ##################################### | 100%
# aom-3.13.2           | 2.7 MB    | ##################################### | 100%
# xorg-libxi-1.8.2     | 46 KB     | ##################################### | 100%
# libpng-1.6.56        | 243 KB    | ##################################### | 100%
# traitlets-5.14.3     | 179 KB    | ##################################### | 100%
# xorg-libxxf86vm-1.1. | 16 KB     | ##################################### | 100%
# conda-25.9.1         | 923 KB    | ##################################### | 100%
# lcms2-2.19           | 243 KB    | ##################################### | 100%
# libgl-1.7.0          | 149 KB    | ##################################### | 100%
# reproc-14.2.7        | 32 KB     | ##################################### | 100%
# patchelf-0.17.2      | 98 KB     | ##################################### | 100%
# _openmp_mutex-5.1    | 7 KB      | ##################################### | 100%
# libevent-2.1.12      | 453 KB    | ##################################### | 100%
# pydantic-settings-2. | 102 KB    | ##################################### | 100%
# c-ares-1.34.7        | 204 KB    | ##################################### | 100%
# anaconda-client-1.13 | 767 KB    | ##################################### | 100%
# libsodium-1.0.21     | 287 KB    | ##################################### | 100%
# annotated-types-0.6. | 22 KB     | ##################################### | 100%
# filelock-3.17.0      | 32 KB     | ##################################### | 100%
# msgpack-python-1.1.1 | 112 KB    | ##################################### | 100%
# babel-2.16.0         | 6.8 MB    | ##################################### | 100%
# typer-0.17.4         | 122 KB    | ##################################### | 100%
# libre2-11-2025.11.05 | 206 KB    | ##################################### | 100%
# xorg-libsm-1.2.6     | 26 KB     | ##################################### | 100%
# zipp-3.21.0          | 26 KB     | ##################################### | 100%
# send2trash-1.8.2     | 27 KB     | ##################################### | 100%
# libmambapy-2.3.2     | 647 KB    | ##################################### | 100%
# zeromq-4.3.5         | 338 KB    | ##################################### | 100%
# notebook-shim-0.2.4  | 22 KB     | ##################################### | 100%
# wcwidth-0.2.13       | 70 KB     | ##################################### | 100%
# libavif-1.3.0        | 151 KB    | ##################################### | 100%
# yaml-0.2.5           | 74 KB     | ##################################### | 100%
# click-8.1.8          | 271 KB    | ##################################### | 100%
# xorg-libxtst-1.2.5   | 31 KB     | ##################################### | 100%
# anaconda-auth-0.10.0 | 68 KB     | ##################################### | 100%
# qttools-6.9.2        | 6.1 MB    | ##################################### | 100%
# jaraco.context-6.0.0 | 15 KB     | ##################################### | 100%
# qtwebengine-6.9.2    | 108.5 MB  | ##################################### | 100%
# matplotlib-inline-0. | 17 KB     | ##################################### | 100%
# intel-openmp-2025.0. | 19.3 MB   | ##################################### | 100%
# chardet-5.2.0        | 1.9 MB    | ##################################### | 100%
# psutil-7.0.0         | 416 KB    | ##################################### | 100%
# readchar-4.2.1       | 19 KB     | ##################################### | 100%
# semver-3.0.4         | 38 KB     | ##################################### | 100%
# fmt-11.2.0           | 202 KB    | ##################################### | 100%
# libexpat-2.8.2       | 126 KB    | ##################################### | 100%
# conda-package-stream | 32 KB     | ##################################### | 100%
# python-json-logger-3 | 24 KB     | ##################################### | 100%
# qtwebsockets-6.9.2   | 126 KB    | ##################################### | 100%
# beautifulsoup4-4.13. | 215 KB    | ##################################### | 100%
# libunistring-1.4.2   | 656 KB    | ##################################### | 100%
# rpds-py-0.22.3       | 369 KB    | ##################################### | 100%
# mkl_fft-1.3.11       | 219 KB    | ##################################### | 100%
# pyzmq-27.1.0         | 326 KB    | ##################################### | 100%
# zstandard-0.24.0     | 396 KB    | ##################################### | 100%
# xcb-util-image-0.4.0 | 23 KB     | ##################################### | 100%
# python-dotenv-1.1.0  | 39 KB     | ##################################### | 100%
# conda-repo-cli-1.0.1 | 160 KB    | ##################################### | 100%
# libdeflate-1.22      | 68 KB     | ##################################### | 100%
# python-dateutil-2.9. | 279 KB    | ##################################### | 100%
# libglvnd-1.7.0       | 140 KB    | ##################################### | 100%
# libglx-1.7.0         | 87 KB     | ##################################### | 100%
# libstdcxx-ng-15.2.0  | 28 KB     | ##################################### | 100%
# jedi-0.19.2          | 1.1 MB    | ##################################### | 100%
# nlohmann_json-3.11.2 | 124 KB    | ##################################### | 100%
# mysql-common-9.3.0   | 612 KB    | ##################################### | 100%
# jsonpatch-1.33       | 31 KB     | ##################################### | 100%
# gettext-0.25.1       | 523 KB    | ##################################### | 100%
# tabulate-0.9.0       | 52 KB     | ##################################### | 100%
# libasprintf-0.25.1   | 51 KB     | ##################################### | 100%
# boltons-25.0.0       | 426 KB    | ##################################### | 100%
# ujson-5.10.0         | 141 KB    | ##################################### | 100%
# mesalib-25.1.5       | 8.3 MB    | ##################################### | 100%
# future-1.0.0         | 684 KB    | ##################################### | 100%
# anaconda-anon-usage- | 24 KB     | ##################################### | 100%
# numpy-base-2.0.2     | 7.4 MB    | ##################################### | 100%
# xorg-libice-1.1.2    | 57 KB     | ##################################### | 100%
# jsonschema-4.25.0    | 156 KB    | ##################################### | 100%
# ipykernel-6.30.1     | 198 KB    | ##################################### | 100%
# pixman-0.46.4        | 329 KB    | ##################################### | 100%
# packaging-25.0       | 160 KB    | ##################################### | 100%
# libssh2-1.11.1       | 296 KB    | ##################################### | 100%
# typing_extensions-4. | 79 KB     | ##################################### | 100%
# libmamba-2.3.2       | 2.0 MB    | ##################################### | 100%
# tornado-6.5.1        | 667 KB    | ##################################### | 100%
# jupyter_events-0.12. | 37 KB     | ##################################### | 100%
# libvpx-1.15.2        | 1.2 MB    | ##################################### | 100%
# menuinst-2.4.1       | 221 KB    | ##################################### | 100%
# decorator-5.2.1      | 38 KB     | ##################################### | 100%
# ncurses-6.5          | 1.1 MB    | ##################################### | 100%
# harfbuzz-10.2.0      | 2.3 MB    | ##################################### | 100%
# xorg-libxfixes-6.0.1 | 18 KB     | ##################################### | 100%
# qtpy-2.4.3           | 109 KB    | ##################################### | 100%
# archspec-0.2.5       | 48 KB     | ##################################### | 100%
# importlib_metadata-8 | 9 KB      | ##################################### | 100%
# mkl_random-1.3.0     | 301 KB    | ##################################### | 100%
# snappy-1.2.2         | 46 KB     | ##################################### | 100%
# navigator-updater-0. | 2.1 MB    | ##################################### | 100%
# parso-0.8.4          | 188 KB    | ##################################### | 100%
# nbconvert-core-7.16. | 475 KB    | ##################################### | 100%
# libgcc-15.2.0        | 803 KB    | ##################################### | 100%
# mdurl-0.1.2          | 23 KB     | ##################################### | 100%
# jpeg-9f              | 242 KB    | ##################################### | 100%
# xorg-libxext-1.3.6   | 49 KB     | ##################################### | 100%
# libpciaccess-0.18    | 26 KB     | ##################################### | 100%
# openssl-3.5.7        | 5.5 MB    | ##################################### | 100%
# lz4-c-1.9.4          | 144 KB    | ##################################### | 100%
# libtiff-4.7.1        | 423 KB    | ##################################### | 100%
# libasprintf-devel-0. | 33 KB     | ##################################### | 100%
# pydantic-2.12.2      | 874 KB    | ##################################### | 100%
# jupyter-lsp-2.2.5    | 92 KB     | ##################################### | 100%
# pysocks-1.7.1        | 29 KB     | ##################################### | 100%
# pkce-1.0.3           | 8 KB      | ##################################### | 100%
# fribidi-1.0.16       | 58 KB     | ##################################### | 100%
# ld_impl_linux-64-2.4 | 725 KB    | ##################################### | 100%
# qtsvg-6.9.2          | 305 KB    | ##################################### | 100%
# rfc3986-validator-0. | 9 KB      | ##################################### | 100%
# tqdm-4.67.1          | 133 KB    | ##################################### | 100%
# nbformat-5.10.4      | 138 KB    | ##################################### | 100%
# libxslt-1.1.43       | 240 KB    | ##################################### | 100%
# libzlib-1.3.2        | 60 KB     | ##################################### | 100%
# conda-index-0.7.0    | 233 KB    | ##################################### | 100%
# mysql-libs-9.3.0     | 1.3 MB    | ##################################### | 100%
# wheel-0.45.1         | 114 KB    | ##################################### | 100%
# markdown-it-py-2.2.0 | 113 KB    | ##################################### | 100%
# shellingham-1.5.4    | 19 KB     | ##################################### | 100%
# prometheus_client-0. | 121 KB    | ##################################### | 100%
# pycosat-0.6.6        | 88 KB     | ##################################### | 100%
# debugpy-1.8.16       | 2.1 MB    | ##################################### | 100%
# libdrm-2.4.134       | 305 KB    | ##################################### | 100%
# ipython-8.15.0       | 1.1 MB    | ##################################### | 100%
# pycparser-2.23       | 224 KB    | ##################################### | 100%
# nest-asyncio-1.6.0   | 14 KB     | ##################################### | 100%
# openldap-2.6.12      | 760 KB    | ##################################### | 100%
# tbb-devel-2022.3.0   | 1.1 MB    | ##################################### | 100%
# ruamel.yaml-0.18.10  | 202 KB    | ##################################### | 100%
# ptyprocess-0.7.0     | 18 KB     | ##################################### | 100%
# markupsafe-3.0.2     | 24 KB     | ##################################### | 100%
# libarchive-3.8.2     | 855 KB    | ##################################### | 100%
# tzdata-2026c         | 117 KB    | ##################################### | 100%
# pexpect-4.9.0        | 138 KB    | ##################################### | 100%
# jupyter_server-2.16. | 499 KB    | ##################################### | 100%
# fontconfig-2.15.0    | 262 KB    | ##################################### | 100%
# qtshadertools-6.9.2  | 1.7 MB    | ##################################### | 100%
# expat-2.8.2          | 24 KB     | ##################################### | 100%
# importlib-metadata-8 | 44 KB     | ##################################### | 100%
# secretstorage-3.3.1  | 26 KB     | ##################################### | 100%
# jansson-2.15.0       | 65 KB     | ##################################### | 100%
# rfc3339-validator-0. | 9 KB      | ##################################### | 100%
# libgcc-ng-15.2.0     | 28 KB     | ##################################### | 100%
# requests-2.32.5      | 149 KB    | ##################################### | 100%
# platformdirs-4.3.7   | 36 KB     | ##################################### | 100%
# jaraco.functools-4.1 | 20 KB     | ##################################### | 100%
# zstd-1.5.7           | 608 KB    | ##################################### | 100%
# xcb-util-cursor-0.1. | 19 KB     | ##################################### | 100%
# libopus-1.6.1        | 289 KB    | ##################################### | 100%
# xkeyboard-config-2.4 | 887 KB    | ##################################### | 100%
# pybind11-abi-4       | 14 KB     | ##################################### | 100%
# sqlite-3.53.2        | 1.2 MB    | ##################################### | 100%
# liblief-0.16.4       | 2.1 MB    | ##################################### | 100%
# qtbase-6.9.2         | 11.1 MB   | ##################################### | 100%
# typing-extensions-4. | 11 KB     | ##################################### | 100%
# terminado-0.18.1     | 28 KB     | ##################################### | 100%
# libgettextpo-devel-0 | 35 KB     | ##################################### | 100%
# conda-libmamba-solve | 39 KB     | ##################################### | 100%
# libpq-17.6           | 2.5 MB    | ##################################### | 100%
# cpp-expected-1.1.0   | 130 KB    | ##################################### | 100%
# pthread-stubs-0.3    | 7 KB      | ##################################### | 100%
# requests-toolbelt-1. | 72 KB     | ##################################### | 100%
# mkl-service-2.5.2    | 72 KB     | ##################################### | 100%
# tk-8.6.15            | 3.4 MB    | ##################################### | 100%
# backports-1.1        | 6 KB      | ##################################### | 100%
# reproc-cpp-14.2.7    | 24 KB     | ##################################### | 100%
# gettext-tools-0.25.1 | 3.6 MB    | ##################################### | 100%
# qtdeclarative-6.9.2  | 16.7 MB   | ##################################### | 100%
# charset-normalizer-3 | 79 KB     | ##################################### | 100%
# jupyterlab_pygments- | 18 KB     | ##################################### | 100%
# keyring-25.6.0       | 68 KB     | ##################################### | 100%
# jupyter_client-8.6.3 | 184 KB    | ##################################### | 100%
# anyio-4.10.0         | 224 KB    | ##################################### | 100%
# jsonschema-specifica | 15 KB     | ##################################### | 100%
# lmdb-1.0.0           | 518 KB    | ##################################### | 100%
# ca-certificates-2026 | 106 KB    | ##################################### | 100%
# mkl-2025.0.0         | 113.4 MB  | ##################################### | 100%
# mistune-3.1.2        | 117 KB    | ##################################### | 100%
# graphite2-1.3.15     | 93 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install seaborn matplotlib
# Out:
# Retrieving notices: done
# Channels:
#  -
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are missing from the target environment:
#
#   - matplotlib
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 1. Carregar dados

# %%
# Leitura do arquivo csv da base de dados 
# Carrega os 72530 registros de acidentes para o dataframe chamado "prf_acidentes_2025"
prf_acidentes_2025 = pd.read_csv("acidentes2025.csv", encoding="ISO-8859-1", sep=";")

# %%
# Conversão da coluna de data de texto para o tipo datetime 
# Necessário para permitir agrupamento por mês / ano e cálculos de série temporal 
prf_acidentes_2025["data_inversa"] = pd.to_datetime(prf_acidentes_2025["data_inversa"])

# %%
# Exibição do formato da base (linhas, colunas) 
# Primeira conferência: confirma que os 72530 acidentes e as 30 colunas foram carregados corretamente 
print(prf_acidentes_2025.shape)
# Out:
# (72529, 30)

# %% [markdown]
# #### Análise por tipo de acidente

# %%
### Criar colunas auxiliares 
prf_acidentes_2025['acidente_fatal'] = prf_acidentes_2025['mortos'].apply(lambda x: 1 if x > 1 else 0)

# %%
prf_acidentes_2025['total_vitimas'] = prf_acidentes_2025[['mortos', 'feridos_leves', 'feridos_graves']].sum(axis=1)

# %% [markdown]
# #### Indicadores globais

# %%
total_acidentes = len(prf_acidentes_2025)

# %%
total_vitimas = prf_acidentes_2025['total_vitimas'].sum()

# %%
total_acidentes_fatais = prf_acidentes_2025['acidente_fatal'].sum()

# %%
percentual_acidentes_fatais = (total_acidentes_fatais / total_acidentes) * 100

# %%
taxa_letalidade = (prf_acidentes_2025['mortos'].sum() / total_vitimas) * 100

# %%
print(f"Total de Acidentes: {total_acidentes}")
# Out:
# Total de Acidentes: 72529

# %%
print(f"Total de Vítimas: {total_vitimas}")
# Out:
# Total de Vítimas: 89593

# %%
print(f"Total de Acidentes Fatais: {total_acidentes_fatais}")
# Out:
# Total de Acidentes Fatais: 578

# %%
print(f"Percentual de Acidentes Fatais: {percentual_acidentes_fatais:.2f}%")
# Out:
# Percentual de Acidentes Fatais: 0.80%

# %%
print(f"Taxa de Letalidade Operacional: {taxa_letalidade:.2f}%")
# Out:
# Taxa de Letalidade Operacional: 6.74%

# %%
#### 4. Análise espacial poR UF e BR 
analise_espacial = prf_acidentes_2025.groupby(['uf', 'br']).agg({
    
    'id': 'count', 
    'acidente_fatal': 'sum', 
    'mortos': 'sum', 
    'total_vitimas': 'sum'
    
}).rename(columns = {'id':'total_acidentes'} )

# %%
analise_espacial['taxa_letalidade'] = ((analise_espacial['mortos'] / analise_espacial['total_vitimas']) * 100).round(2)

# %%
analise_espacial.sort_values(by = 'taxa_letalidade', ascending = False).head(10)
# Out:
#         total_acidentes  acidente_fatal  mortos  total_vitimas  \
# uf br
# AM 317                1               0       1              1
# RR 210                1               0       1              1
# CE 403                6               0       3              5
# MA 330                5               3       9             15
# CE 230               22               1      13             32
# BA 30                 4               0       2              5
# PA 222               37               3      21             59
# AL 416               13               0       6             17
# CE 226                7               1       5             15
# MA 402               26               2      11             34
#
#         taxa_letalidade
# uf br
# AM 317           100.00
# RR 210           100.00
# CE 403            60.00
# MA 330            60.00
# CE 230            40.62
# BA 30             40.00
# PA 222            35.59
# AL 416            35.29
# CE 226            33.33
# MA 402            32.35

# %% [markdown]
# #### Análise das Causas dos Acidentes e Letalidade

# %%
# Agrupar a coluna  causa_acidente e calcular total, totais fatais e taxa de letalidade 
analise_causa = prf_acidentes_2025.groupby('causa_acidente').agg({
    
    'id': 'count', 
    'mortos': 'sum', 
    'total_vitimas': 'sum'
    
}).rename(columns={'id': 'total_acidentes'})

# %%
analise_causa['taxa_letalidade'] = (analise_causa['mortos'] / analise_causa['total_vitimas'] * 100).round(2)

# %%
# Ordenar pela taxa de letalidade 
analise_causa = analise_causa.sort_values(by='taxa_letalidade', ascending = False)

# %%
print(analise_causa.head(10))
# Out:
#                                                     total_acidentes  mortos  \
# causa_acidente
# Suicídio (presumido)                                            190     111
# Pedestre andava na pista                                        606     252
# Entrada inopinada do pedestre                                   667     209
# Transitar na contramão                                         2475     961
# Pedestre cruzava a pista fora da faixa                          525     133
# Participar de racha                                              22       7
# Transtornos Mentais (exceto suicidio)                            59      10
# Falta de acostamento                                             60      11
# Pedestre - Ingestão de álcool/ substâncias psic...              150      28
# Semáforo com defeito                                              8       1
#
#                                                     total_vitimas  \
# causa_acidente
# Suicídio (presumido)                                          209
# Pedestre andava na pista                                      717
# Entrada inopinada do pedestre                                 791
# Transitar na contramão                                       4413
# Pedestre cruzava a pista fora da faixa                        667
# Participar de racha                                            36
# Transtornos Mentais (exceto suicidio)                          61
# Falta de acostamento                                           69
# Pedestre - Ingestão de álcool/ substâncias psic...            191
# Semáforo com defeito                                            7
#
#                                                     taxa_letalidade
# causa_acidente
# Suicídio (presumido)                                          53.11
# Pedestre andava na pista                                      35.15
# Entrada inopinada do pedestre                                 26.42
# Transitar na contramão                                        21.78
# Pedestre cruzava a pista fora da faixa                        19.94
# Participar de racha                                           19.44
# Transtornos Mentais (exceto suicidio)                         16.39
# Falta de acostamento                                          15.94
# Pedestre - Ingestão de álcool/ substâncias psic...            14.66
# Semáforo com defeito                                          14.29

# %%
# Visualização: top 10 causas por taxa de letalidade
plt.figure(figsize=(12,6))
sns.barplot(x=analise_causa.head(10).index, y='taxa_letalidade', data=analise_causa.head(10), palette = 'Reds_r') 
plt.xticks(rotation = 45, ha='right') 
plt.title('Top 10 Causas de Acidentes por Taxa de Letalidade (%)') 
plt.ylabel('Taxa de Letalidade (%)') 
plt.xlabel('Causa de Acidente') 
plt.tight_layout() 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3697/1096159943.py in <module>
#       1 # Visualização: top 10 causas por taxa de letalidade
# ----> 2 plt.figure(figsize=(12,6))
#
# NameError: name 'plt' is not defined
